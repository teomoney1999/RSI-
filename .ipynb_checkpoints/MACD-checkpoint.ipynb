# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("NASDAQOMX-XQC.csv")

# %%
data = data.sort_values(by='Trade Date')

# %%
data = data.set_index('Trade Date')

# %%
def calculate_ema(series_y, day): 
    return series_y.ewm(span=day).mean()

# %%
data['EMA-12day'] = calculate_ema(data['Index Value'], 12)
data['EMA-26day'] = calculate_ema(data['Index Value'], 26)

# %%
price_line = data[['Index Value','EMA-12day', 'EMA-26day']].head(100).plot(figsize=(10,10))

# %%
# Out:
#      Trade Date  Index Value  High  Low  Total Market Value  \
# 880  2016-12-19      4934.85   0.0  0.0                 0.0
# 879  2016-12-20      4953.80   0.0  0.0                 0.0
#
#      Dividend Market Value    EMA-12day    EMA-26day
# 880                    0.0  4934.850000  4934.850000
# 879                    0.0  4945.114583  4944.689423

# %%
data['MACD-diff'] = data['EMA-12day'] - data['EMA-26day']

# %%
data['MACD(9, 12, 26)'] = calculate_ema(data['MACD-diff'], 9)

# %%
data[['MACD-diff', 'MACD(9, 12, 26)']].head(100).plot(figsize=(10, 5))

# %%
data['MACD Histogram'] = data['MACD-diff'] - data['MACD(9, 12, 26)']

# %%
data[['MACD-diff', 'MACD(9, 12, 26)', 'MACD Histogram']].head(100).plot(figsize=(10, 5))

# %%
data.head(5)
# Out:
#             Index Value  High  Low  Total Market Value  Dividend Market Value  \
# Trade Date
# 2016-12-19      4934.85   0.0  0.0                 0.0                    0.0
# 2016-12-20      4953.80   0.0  0.0                 0.0                    0.0
# 2016-12-21      4948.90   0.0  0.0                 0.0                    0.0
# 2016-12-22      4934.39   0.0  0.0                 0.0                    0.0
# 2016-12-23      4940.02   0.0  0.0                 0.0                    0.0
#
#               EMA-12day    EMA-26day  MACD-diff  MACD(9, 12, 26)  \
# Trade Date
# 2016-12-19  4934.850000  4934.850000   0.000000         0.000000
# 2016-12-20  4945.114583  4944.689423   0.425160         0.236200
# 2016-12-21  4946.592032  4946.202242   0.389790         0.299147
# 2016-12-22  4942.740328  4942.900056  -0.159728         0.143701
# 2016-12-23  4942.001224  4942.232159  -0.230935         0.032256
#
#             MACD Histogram
# Trade Date
# 2016-12-19        0.000000
# 2016-12-20        0.188960
# 2016-12-21        0.090643
# 2016-12-22       -0.303429
# 2016-12-23       -0.263190

# %%
data['High'] = data['Index Value'].diff()

# %%
data['Low'] = 0

# %%
data['Low'] = data[data['High'] < 0]

# %%
data.head()
# Out:
#             Index Value   High      Low  Total Market Value  \
# Trade Date
# 2016-12-19      4934.85    NaN      NaN                 0.0
# 2016-12-20      4953.80  18.95      NaN                 0.0
# 2016-12-21      4948.90  -4.90  4948.90                 0.0
# 2016-12-22      4934.39 -14.51  4934.39                 0.0
# 2016-12-23      4940.02   5.63      NaN                 0.0
#
#             Dividend Market Value    EMA-12day    EMA-26day  MACD-diff  \
# Trade Date
# 2016-12-19                    0.0  4934.850000  4934.850000   0.000000
# 2016-12-20                    0.0  4945.114583  4944.689423   0.425160
# 2016-12-21                    0.0  4946.592032  4946.202242   0.389790
# 2016-12-22                    0.0  4942.740328  4942.900056  -0.159728
# 2016-12-23                    0.0  4942.001224  4942.232159  -0.230935
#
#             MACD(9, 12, 26)  MACD Histogram
# Trade Date
# 2016-12-19         0.000000        0.000000
# 2016-12-20         0.236200        0.188960
# 2016-12-21         0.299147        0.090643
# 2016-12-22         0.143701       -0.303429
# 2016-12-23         0.032256       -0.263190
