# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
btc = pd.read_csv('NASDAQOMX-XQC.csv')

# %%
btc.head()
# Out:
#      Trade Date  Index Value  High  Low  Total Market Value  \
# 880  2016-12-19      4934.85   0.0  0.0                 0.0
# 879  2016-12-20      4953.80   0.0  0.0                 0.0
# 878  2016-12-21      4948.90   0.0  0.0                 0.0
# 877  2016-12-22      4934.39   0.0  0.0                 0.0
# 876  2016-12-23      4940.02   0.0  0.0                 0.0
#
#      Dividend Market Value
# 880                    0.0
# 879                    0.0
# 878                    0.0
# 877                    0.0
# 876                    0.0

# %%
btc = btc.sort_values(by='Trade Date')

# %%
btc['Index Value'].plot(figsize=(10,10))
